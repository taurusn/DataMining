# %% [markdown]
# # 🤖 Machine Learning Models\n
# ## Electronics Sales Data Mining Project\n\n
# This notebook trains and compares different ML models.\n\n
# ### 🎯 Models:\n
# - Logistic Regression\n
# - Decision Tree\n
# - Random Forest\n
# - Parameter tuning and optimization\n\n
# ---
