# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA)
# ## Electronics Sales Data Mining Project
#
# This notebook performs initial exploration of the electronics sales dataset (Sept 2023 - Sept 2024).
#
# ### 🎯 Objectives:
# - Load and examine the raw dataset structure
# - Identify data quality issues
# - Explore statistical summaries and distributions
# - Visualize key patterns and relationships
# - Generate insights for preprocessing steps
#
# ---
