# %% [markdown]
# # 📈 Model Evaluation\n
# ## Electronics Sales Data Mining Project\n\n
# This notebook evaluates model performance and compares results.\n\n
# ### 🎯 Metrics:\n
# - Accuracy, Precision, Recall, F1-score\n
# - ROC-AUC curves\n
# - Confusion matrices\n
# - Model comparison and selection\n\n
# ---
